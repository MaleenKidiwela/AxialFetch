# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
# Out:
# 2025-05-17 19:04:53.180708: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-17 19:04:53.226507: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-17 19:04:53.911841: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load by file name
R2502_2503 = pd.read_pickle("R2502_2503.pkl")
R2503_2502 = pd.read_pickle("R2503_2502.pkl")
R2503_2504 = pd.read_pickle("R2503_2504.pkl")
R2504_2503 = pd.read_pickle("R2504_2503.pkl")
R2502_2504 = pd.read_pickle("R2502_2504.pkl")
R2504_2502 = pd.read_pickle("R2504_2502.pkl")

F2504 = pd.read_pickle("2504.pkl")

# %%
from pathlib import Path

# 1) Does a directory exist?
base = Path("/home/seismic/AxialFetch/MJ03F-B")
print(base, "→", base.exists(), "(dir)" if base.is_dir() else "(not a dir)")

# 2) Does one specific file exist?
f = base / "MJ03F-B2022DIFF-PRESS-15min.txt"
print(f, "→", f.exists())

# 3) Quick sweep over a pattern
for p in base.glob("MJ03F-B*DIFF-PRESS-15min.txt"):
    print("found:", p.name)
# Out:
# /home/seismic/AxialFetch/MJ03F-B → True (dir)
# /home/seismic/AxialFetch/MJ03F-B/MJ03F-B2022DIFF-PRESS-15min.txt → True
# found: MJ03F-B2023DIFF-PRESS-15min.txt
# found: MJ03F-B2022DIFF-PRESS-15min.txt
# found: MJ03F-B2021DIFF-PRESS-15min.txt
# found: MJ03F-B2020DIFF-PRESS-15min.txt
# found: MJ03F-B2019DIFF-PRESS-15min.txt
# found: MJ03F-B2018DIFF-PRESS-15min.txt
# found: MJ03F-B2017DIFF-PRESS-15min.txt
# found: MJ03F-B2024DIFF-PRESS-15min.txt

# %%
# MJ03F-B depth / pressure processing
# ----------------------------------
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

base_path = Path("/home/seismic/AxialFetch/MJ03F-B")
years     = range(2022, 2025)      # 2022-2024
factor    = 0.67                   # pressure-to-depth conversion

def load_series(years, suffix):
    """Read MJ03F-B DIFF-PRESS files (comma OR whitespace delimited)."""
    frames = []

    for yr in years:
        f = base_path / f"MJ03F-B{yr}DIFF-PRESS-{suffix}.txt"
        if not f.exists():
            continue

        # ---- peek at first line to decide the delimiter -----------------
        with open(f, "r") as fh:
            first_line = fh.readline()

        comma = "," in first_line
        read_opts = dict(
            comment="#",
            engine="python",          # tolerant, handles weird rows
            on_bad_lines="skip"       # silently drop malformed lines
        )

        if comma:
            df = pd.read_csv(f, **read_opts)
            # pick the known columns
            date_col      = df.columns[0]                       # e.g. 'date_1day'
            pressure_col  = (
                "pressure_diff_mean"
                if "pressure_diff_mean" in df.columns
                else df.columns[-1]                             # last numeric col
            )
            df = df[[date_col, pressure_col]]
            df.columns = ["time", "pressure_diff"]
        else:
            # whitespace version: two numeric cols after the date
            df = pd.read_csv(
                f,
                delim_whitespace=True,
                header=None,
                names=["time", "pressure_diff"],
                **read_opts,
            )

        # ---- type conversions & cleanup -------------------------------
        df["time"] = pd.to_datetime(df["time"], format="%Y/%m/%d",
                                    errors="coerce", utc=True)
        df["pressure_diff"] = pd.to_numeric(df["pressure_diff"],
                                            errors="coerce")
        df.dropna(subset=["time", "pressure_diff"], inplace=True)
        frames.append(df)

    if not frames:
        raise FileNotFoundError(f"No DIFF-PRESS-{suffix} data found.")
    return pd.concat(frames, ignore_index=True).sort_values("time")

# ----------------------------------------------------------------------
df_15min = load_series(years, "15min")
df_1day  = load_series(years, "1daymeans")

df_15min["depth_m"] = df_15min["pressure_diff"] * factor
df_1day ["depth_m"] = df_1day ["pressure_diff"] * factor

# minimalist (time, pressure) DF
df_pressure = df_1day[["time", "pressure_diff"]]

print("Rows in df_pressure:", len(df_pressure))   # sanity check

# ----------------------------------------------------------------------
# quick plot
plt.figure(figsize=(13, 7))
plt.plot(df_15min["time"], df_15min["depth_m"],
         label="15-minute", linewidth=0.7)
plt.plot(df_1day["time"],  df_1day["depth_m"],
         label="1-day mean", linewidth=2)
plt.gca().invert_yaxis()
plt.xlabel("Date")
plt.ylabel("Depth difference (m)")
plt.title("MJ03F-B Depth Difference 2022-2024")
plt.xlim(pd.Timestamp(2022, 9, 1, tz="UTC"),
         pd.Timestamp(2024, 10, 1, tz="UTC"))
#plt.ylim(-14.55, -14.45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

del df_1day
# Out:
# Rows in df_pressure: 994

# %%
# MJ03F-B depth / pressure processing
# ----------------------------------
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

base_path = Path("/home/seismic/AxialFetch/MJ03F-E")
years     = range(2022, 2025)      # 2022-2024
factor    = 0.67                   # pressure-to-depth conversion

def load_series(years, suffix):
    """Read MJ03F-E DIFF-PRESS files (comma OR whitespace delimited)."""
    frames = []

    for yr in years:
        f = base_path / f"MJ03F-E{yr}DIFF-PRESS-{suffix}.txt"
        if not f.exists():
            continue

        # ---- peek at first line to decide the delimiter -----------------
        with open(f, "r") as fh:
            first_line = fh.readline()

        comma = "," in first_line
        read_opts = dict(
            comment="#",
            engine="python",          # tolerant, handles weird rows
            on_bad_lines="skip"       # silently drop malformed lines
        )

        if comma:
            df = pd.read_csv(f, **read_opts)
            # pick the known columns
            date_col      = df.columns[0]                       # e.g. 'date_1day'
            pressure_col  = (
                "pressure_diff_mean"
                if "pressure_diff_mean" in df.columns
                else df.columns[-1]                             # last numeric col
            )
            df = df[[date_col, pressure_col]]
            df.columns = ["time", "pressure_diff"]
        else:
            # whitespace version: two numeric cols after the date
            df = pd.read_csv(
                f,
                delim_whitespace=True,
                header=None,
                names=["time", "pressure_diff"],
                **read_opts,
            )

        # ---- type conversions & cleanup -------------------------------
        df["time"] = pd.to_datetime(df["time"], format="%Y/%m/%d",
                                    errors="coerce", utc=True)
        df["pressure_diff"] = pd.to_numeric(df["pressure_diff"],
                                            errors="coerce")
        df.dropna(subset=["time", "pressure_diff"], inplace=True)
        frames.append(df)

    if not frames:
        raise FileNotFoundError(f"No DIFF-PRESS-{suffix} data found.")
    return pd.concat(frames, ignore_index=True).sort_values("time")

# ----------------------------------------------------------------------
df_15min = load_series(years, "15min")
df_1day  = load_series(years, "1daymeans")

df_15min["depth_m"] = df_15min["pressure_diff"] * factor
df_1day ["depth_m"] = df_1day ["pressure_diff"] * factor

# minimalist (time, pressure) DF
df_pressure1 = df_1day[["time", "pressure_diff"]]

print("Rows in df_pressure:", len(df_pressure))   # sanity check

# ----------------------------------------------------------------------
# quick plot
plt.figure(figsize=(13, 7))
plt.plot(df_15min["time"], df_15min["depth_m"],
         label="15-minute", linewidth=0.7)
plt.plot(df_1day["time"],  df_1day["depth_m"],
         label="1-day mean", linewidth=2)
plt.gca().invert_yaxis()
plt.xlabel("Date")
plt.ylabel("Depth difference (m)")
plt.title("MJ03F-E Depth Difference 2022-2024")
plt.xlim(pd.Timestamp(2022, 9, 1, tz="UTC"),
         pd.Timestamp(2024, 10, 1, tz="UTC"))
plt.ylim(8.6, 8.47)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Rows in df_pressure: 994

# %%
import pandas as pd

# ------------------------------------------------------------------
# 1) helper → convert any table to a clean UTC-indexed Series
# ------------------------------------------------------------------
def to_series(df, time_col, value_col, fmt=None):
    s = (
        df[[time_col, value_col]]
        .assign(**{time_col: lambda d: pd.to_datetime(
            d[time_col], format=fmt, utc=True)})
        .set_index(time_col)[value_col]
        .astype(float)
        .sort_index()
        .loc[lambda x: ~x.index.duplicated(keep="first")]
    )
    return s

# ------------------------------------------------------------------
# 2) build the master grid from R2503_2504  (distance d1)
# ------------------------------------------------------------------
d1 = to_series(R2503_2502, "Record Time", "Moving Average")

df_var = d1.to_frame("d1")   # index = time, one column so far

# ------------------------------------------------------------------
# 3) prepare the other source series
# ------------------------------------------------------------------
# pressure difference p1 (comes from df_pressure)
p1 = (
    df_pressure.assign(time=pd.to_datetime(df_pressure["time"], utc=True))
               .set_index("time")["pressure_diff"]
               .astype(float)
               .sort_index()
               .loc[lambda x: ~x.index.duplicated(keep="first")]
)

p2 = (
    df_pressure1.assign(time=pd.to_datetime(df_pressure1["time"], utc=True))
               .set_index("time")["pressure_diff"]
               .astype(float)
               .sort_index()
               .loc[lambda x: ~x.index.duplicated(keep="first")]
)

# distance opposite direction d2
d2 = to_series(R2502_2503, "Record Time", "Moving Average")
d3 = to_series(R2502_2504, "Record Time", "Moving Average")
d4 = to_series(R2504_2502, "Record Time", "Moving Average")
d5 = to_series(R2503_2504, "Record Time", "Moving Average")
d6 = to_series(R2504_2503, "Record Time", "Moving Average")

# corrected pressure p2
p3 = to_series(F2504, "DateTime", "Corrected Pressure (kPa)")

# %%
# ------------------------------------------------------------------
# 4) interpolate everything onto the master grid
# ------------------------------------------------------------------
def onto_master(source, master_index):
    union = source.reindex(master_index.union(source.index))
    filled = union.interpolate("time")
    return filled.reindex(master_index)

df_var["p1"] = onto_master(p1, df_var.index)
df_var["d2"] = onto_master(d2, df_var.index)
df_var["p2"] = onto_master(p2, df_var.index)
df_var["p3"] = onto_master(p3, df_var.index)
df_var["d3"] = onto_master(d3, df_var.index)
df_var["d4"] = onto_master(d4, df_var.index)
df_var["d5"] = onto_master(d5, df_var.index)
df_var["d6"] = onto_master(d6, df_var.index)

# optional order
df_var = df_var[["p1", "p2", "p3", "d1", "d2", "d3", "d4", "d5", "d6"]]

# reset index so 'time' is a normal column
df_var = df_var.reset_index().rename(columns={"index": "time"})

# %%
import os
# -----------------------------------------------------------------------------
# 0) FORCE CPU PARALLELISM TO 48 CORES
# -----------------------------------------------------------------------------
os.environ["OMP_NUM_THREADS"]      = "48"
os.environ["MKL_NUM_THREADS"]      = "48"
os.environ["OPENBLAS_NUM_THREADS"] = "48"

import numpy as np
import pandas as pd
from itertools import product
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, Model, backend as K, callbacks

# Tell TensorFlow to use 48 threads
tf.config.threading.set_intra_op_parallelism_threads(48)
tf.config.threading.set_inter_op_parallelism_threads(48)

# %%
import os
# -----------------------------------------------------------------------------
# USE 48 CORES
# -----------------------------------------------------------------------------
os.environ["OMP_NUM_THREADS"]      = "48"
os.environ["MKL_NUM_THREADS"]      = "48"
os.environ["OPENBLAS_NUM_THREADS"] = "48"

import numpy as np
import pandas as pd
from itertools import product
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import tensorflow as tf
from tensorflow.keras import layers, Model, backend as K, callbacks

# configure TensorFlow threading
tf.config.threading.set_intra_op_parallelism_threads(48)
tf.config.threading.set_inter_op_parallelism_threads(48)

# -----------------------------------------------------------------------------
# 1) PREP DATA (assumes df_var in namespace)
# -----------------------------------------------------------------------------
df_var = df_var.dropna().reset_index(drop=True)
df_var['Record Time'] = pd.to_datetime(df_var['Record Time'], utc=True)
df_var = df_var[df_var['Record Time'] >= pd.Timestamp(2022,9,7,tz='UTC')].reset_index(drop=True)

df = pd.DataFrame({
    'time': df_var['Record Time'],
    'p1':   df_var['p1'], 'p2': df_var['p2'], 'p3': df_var['p3'],
    'r_WE': df_var['d1'], 'r_EW': df_var['d2'], 'r_EC': df_var['d3'],
    'r_CE': df_var['d4'], 'r_WC': df_var['d5'], 'r_CW': df_var['d6'],
})
Y_cols = ['r_WE','r_EW','r_WC','r_CW','r_CE','r_EC']

# time & season
t0 = df['time'].min()
df['t_days'] = (df['time'] - t0).dt.total_seconds()/86400.0
ω = 2*np.pi/365.25
df['sin1'] = np.sin(ω*df['t_days'])
df['cos1'] = np.cos(ω*df['t_days'])

# standardized pressures
p1_std = (df['p1']-df['p1'].mean())/df['p1'].std()
p2_std = (df['p2']-df['p2'].mean())/df['p2'].std()
sin_t, cos_t = df['sin1'].values, df['cos1'].values

# -----------------------------------------------------------------------------
# 2) LEAST-SQUARES BLOCK FITS
# -----------------------------------------------------------------------------
A_CE = np.column_stack([np.ones_like(p2_std), p2_std, sin_t, cos_t])
x_CE,*_ = np.linalg.lstsq(A_CE, df['r_CE'], rcond=None)
x_EC,*_ = np.linalg.lstsq(A_CE, df['r_EC'], rcond=None)
r_CE_lin, r_EC_lin = A_CE@x_CE, A_CE@x_EC

A_CW = np.column_stack([np.ones_like(p1_std), p1_std, sin_t, cos_t])
x_CW,*_ = np.linalg.lstsq(A_CW, df['r_CW'], rcond=None)
x_WC,*_ = np.linalg.lstsq(A_CW, df['r_WC'], rcond=None)
r_CW_lin, r_WC_lin = A_CW@x_CW, A_CW@x_WC

A_EW = np.column_stack([np.ones_like(p1_std), p1_std, p2_std, sin_t, cos_t])
x_EW,*_ = np.linalg.lstsq(A_EW, df['r_EW'], rcond=None)
x_WE,*_ = np.linalg.lstsq(A_EW, df['r_WE'], rcond=None)
r_EW_lin, r_WE_lin = A_EW@x_EW, A_EW@x_WE

R_lin    = np.column_stack([r_WE_lin, r_EW_lin, r_WC_lin, r_CW_lin, r_CE_lin, r_EC_lin]).astype('float32')
R_obs    = df[Y_cols].values.astype('float32')
R_resid  = (R_obs - R_lin).astype('float32')

# -----------------------------------------------------------------------------
# 3) BUILD FEATURE MATRIX & ALIGN
# -----------------------------------------------------------------------------
df_feat = pd.DataFrame({
    'p1':df['p1'],'p2':df['p2'],'p3':df['p3'],
    't_days':df['t_days'],'sin1':df['sin1'],'cos1':df['cos1']
})
for lag in (1,2,3):
    df_feat[f'p1_l{lag}'] = df['p1'].shift(lag)
    df_feat[f'p2_l{lag}'] = df['p2'].shift(lag)
    df_feat[f'p3_l{lag}'] = df['p3'].shift(lag)
for col, arr in zip(
    ['r_WE_lin','r_EW_lin','r_WC_lin','r_CW_lin','r_CE_lin','r_EC_lin'],
    [r_WE_lin, r_EW_lin, r_WC_lin, r_CW_lin, r_CE_lin, r_EC_lin]
):
    df_feat[col] = arr

df_feat.dropna(inplace=True)
df_feat.reset_index(drop=True, inplace=True)

# aligned arrays
idx            = df_feat.index.values
X_raw          = df_feat.values.astype('float32')
R_resid_aligned= R_resid[idx]
R_lin_aligned  = R_lin[idx]
R_true_aligned = R_obs[idx]

# -----------------------------------------------------------------------------
# 4) SCALE & SPLIT LAST 70%
# -----------------------------------------------------------------------------
scaler_X = StandardScaler().fit(X_raw)
Xs       = scaler_X.transform(X_raw)
scaler_R = StandardScaler().fit(R_resid_aligned)
Rs_s     = scaler_R.transform(R_resid_aligned)

N         = Xs.shape[0]
start     = int(0.30 * N)
X_train   = Xs[start:]
Rs_train  = Rs_s[start:]
# we evaluate on full Xs

# constants for un-scaling in loss
mean_R = K.constant(scaler_R.mean_.reshape((1,6)), dtype='float32')
scale_R= K.constant(scaler_R.scale_.reshape((1,6)), dtype='float32')

# indices for LS-features
feat_cols = df_feat.columns.tolist()
i_CE, i_EC = feat_cols.index('r_CE_lin'), feat_cols.index('r_EC_lin')
i_CW, i_WC = feat_cols.index('r_CW_lin'), feat_cols.index('r_WC_lin')
i_WE, i_EW = feat_cols.index('r_WE_lin'), feat_cols.index('r_EW_lin')

# -----------------------------------------------------------------------------
# 5) HYPERPARAMETER GRID SEARCH
# -----------------------------------------------------------------------------
param_grid = {
    'w_mse':   [0.1, 1, 5, 10],
    'w_sym':   [0.01, 0.1, 0.5],
    'w_clo':   [0.01, 0.1, 0.5],
    'w_hinge':[1, 5, 10, 20],
}
results = []

for w_mse, w_sym, w_clo, w_hinge in product(
    param_grid['w_mse'], param_grid['w_sym'],
    param_grid['w_clo'], param_grid['w_hinge']
):
    tf.keras.backend.clear_session()
    inp = layers.Input(shape=(Xs.shape[1],))
    shared = layers.Dense(64, activation='relu')(inp)
    shared = layers.Dense(64, activation='relu')(shared)

    # gather LS features for each head
    east = layers.Lambda(lambda x: tf.gather(x, [i_CE, i_EC], axis=1))(inp)
    west = layers.Lambda(lambda x: tf.gather(x, [i_CW, i_WC], axis=1))(inp)
    mid  = layers.Lambda(lambda x: tf.gather(x, [i_WE, i_EW], axis=1))(inp)

    def head_block(xf):
        xh = layers.Concatenate()([shared, xf])
        xh = layers.Dense(32, activation='relu')(xh)
        return layers.Dense(2)(xh)

    r_CE_p, r_EC_p = tf.split(head_block(east), 2, axis=1)
    r_CW_p, r_WC_p = tf.split(head_block(west), 2, axis=1)
    r_WE_p, r_EW_p = tf.split(head_block(mid), 2, axis=1)

    resid_out = layers.Concatenate()([
        r_WE_p, r_EW_p, r_WC_p, r_CW_p, r_CE_p, r_EC_p
    ])
    model = Model(inp, resid_out)

    def loss_fn(r_true_s, r_pred_s):
        r_true_m = r_true_s * scale_R + mean_R
        r_pred_m = r_pred_s * scale_R + mean_R
        Lm = K.mean(K.square(r_true_s - r_pred_s))
        CE, EC = r_pred_s[:,4], r_pred_s[:,5]
        CW, WC = r_pred_s[:,3], r_pred_s[:,2]
        Ls = K.mean(K.square(CE-EC) + K.square(CW-WC))
        dCE = CE[1:] - CE[:-1]; dCW = CW[1:] - CW[:-1]
        dEW = r_pred_s[1:,1] - r_pred_s[:-1,1]
        Lc = K.mean(K.square(dCE + dCW - dEW))
        delta = K.square(r_true_m - r_pred_m) - K.square(r_true_m)
        Lh = K.mean(K.maximum(delta, 0.0))
        return w_mse*Lm + w_sym*Ls + w_clo*Lc + w_hinge*Lh

    model.compile(optimizer='adam', loss=loss_fn)
    es = callbacks.EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)
    model.fit(X_train, Rs_train, epochs=200, batch_size=len(X_train),
              callbacks=[es], verbose=0)

    # full-series prediction
    Rs_pred_s    = model.predict(Xs)
    Rs_pred      = scaler_R.inverse_transform(Rs_pred_s)
    R_pred_full  = R_lin_aligned + Rs_pred

    r2s = [r2_score(R_true_aligned[:,i], R_pred_full[:,i]) for i in range(6)]
    results.append({
        'w_mse': w_mse, 'w_sym': w_sym,
        'w_clo': w_clo, 'w_hinge': w_hinge,
        'mean_val_R2': np.mean(r2s),
        **{f'R2_{Y_cols[i]}': r2s[i] for i in range(6)}
    })

# display top 5
df_res = pd.DataFrame(results).sort_values('mean_val_R2', ascending=False)
print("Top 5 hyperparameter sets by mean validation R²:")
print(df_res.head(5))
# Out:
# 136/136 [==============================] - 0s 924us/step
# 136/136 [==============================] - 0s 902us/step
# 136/136 [==============================] - 0s 780us/step
# 136/136 [==============================] - 0s 672us/step
# 136/136 [==============================] - 0s 765us/step
# 136/136 [==============================] - 0s 871us/step
# 136/136 [==============================] - 0s 841us/step
# 136/136 [==============================] - 0s 708us/step
# 136/136 [==============================] - 0s 975us/step
# 136/136 [==============================] - 0s 900us/step
# 136/136 [==============================] - 0s 937us/step
# 136/136 [==============================] - 0s 847us/step
# 136/136 [==============================] - 0s 780us/step
# 136/136 [==============================] - 0s 875us/step
# 136/136 [==============================] - 0s 827us/step
# 136/136 [==============================] - 0s 826us/step
# 136/136 [==============================] - 0s 738us/step
# 136/136 [==============================] - 1s 735us/step
# 136/136 [==============================] - 0s 849us/step
# 136/136 [==============================] - 0s 835us/step
# 136/136 [==============================] - 0s 926us/step
# 136/136 [==============================] - 0s 830us/step
# 136/136 [==============================] - 0s 989us/step
# 136/136 [==============================] - 0s 740us/step
# 136/136 [==============================] - 0s 914us/step
# 136/136 [==============================] - 0s 890us/step
# 136/136 [==============================] - 0s 875us/step
# 136/136 [==============================] - 0s 821us/step
# 136/136 [==============================] - 0s 826us/step
# 136/136 [==============================] - 0s 866us/step
# 136/136 [==============================] - 0s 921us/step
# 136/136 [==============================] - 0s 864us/step
# 136/136 [==============================] - 0s 934us/step
# 136/136 [==============================] - 0s 866us/step
# 136/136 [==============================] - 0s 828us/step
# 136/136 [==============================] - 0s 814us/step
# 136/136 [==============================] - 0s 826us/step
# 136/136 [==============================] - 0s 948us/step
# 136/136 [==============================] - 0s 891us/step
# 136/136 [==============================] - 0s 729us/step
# 136/136 [==============================] - 0s 794us/step
# 136/136 [==============================] - 0s 951us/step
# 136/136 [==============================] - 0s 900us/step
# 136/136 [==============================] - 0s 816us/step
# 136/136 [==============================] - 0s 846us/step
# 136/136 [==============================] - 0s 872us/step
# 136/136 [==============================] - 0s 869us/step
# 136/136 [==============================] - 0s 842us/step
# 136/136 [==============================] - 0s 815us/step
# 136/136 [==============================] - 0s 885us/step
# 136/136 [==============================] - 0s 694us/step
# 136/136 [==============================] - 0s 906us/step
# 136/136 [==============================] - 0s 860us/step
# 136/136 [==============================] - 0s 1ms/step
# 136/136 [==============================] - 0s 834us/step
# 136/136 [==============================] - 0s 752us/step
# 136/136 [==============================] - 0s 801us/step
# 136/136 [==============================] - 0s 863us/step
# 136/136 [==============================] - 0s 951us/step
# 136/136 [==============================] - 0s 874us/step
# 136/136 [==============================] - 0s 809us/step
# 136/136 [==============================] - 0s 882us/step
# 136/136 [==============================] - 0s 774us/step
# 136/136 [==============================] - 0s 887us/step
# 136/136 [==============================] - 0s 882us/step
# 136/136 [==============================] - 0s 829us/step
# 136/136 [==============================] - 0s 872us/step
# Top 5 hyperparameter sets by mean validation R²:
#      w_mse  w_sym  w_clo  w_hinge  mean_val_R2   R2_r_WE   R2_r_EW   R2_r_WC  \
# 133   10.0   0.50   0.01        5     0.860820  0.945840  0.895953  0.757214
# 115   10.0   0.01   0.10       20     0.840064  0.902080  0.888231  0.740401
# 91     5.0   0.10   0.10       20     0.835978  0.880806  0.856953  0.704967
# 87     5.0   0.10   0.01       20     0.833838  0.885330  0.839287  0.690086
# 111   10.0   0.01   0.01       20     0.833038  0.923860  0.869820  0.696836
#
#       R2_r_CW   R2_r_CE   R2_r_EC
# 133  0.670876  0.958371  0.936663
# 115  0.609211  0.949658  0.950801
# 91   0.701763  0.937821  0.933560
# 87   0.690567  0.954515  0.943239
# 111  0.621572  0.941360  0.944778

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib, pathlib

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error

import tensorflow as tf
from tensorflow.keras import layers, Model, backend as K, callbacks

# =============================================================================
# THREE-HEAD LS+PINN HYBRID WITH STRICT HINGE LOSS
#    – TRAIN ON LAST 70% – EVALUATE FULL SERIES (CORRECTED)
# =============================================================================

# 0) LOAD & FILTER DATA
df_var = df_var.dropna().reset_index(drop=True)
df_var['Record Time'] = pd.to_datetime(df_var['Record Time'], utc=True)
df_var = df_var[df_var['Record Time'] >= pd.Timestamp(2022,9,7,tz='UTC')].reset_index(drop=True)
df = pd.DataFrame({
    'time': df_var['Record Time'],
    'p1':   df_var['p1'], 'p2': df_var['p2'], 'p3': df_var['p3'],
    'r_WE': df_var['d1'], 'r_EW': df_var['d2'], 'r_EC': df_var['d3'],
    'r_CE': df_var['d4'], 'r_WC': df_var['d5'], 'r_CW': df_var['d6'],
})
Y_cols = ['r_WE','r_EW','r_WC','r_CW','r_CE','r_EC']

# 1) COMPUTE TIME & SEASONAL + LS FITS
t0     = df['time'].min()
df['t_days'] = (df['time']-t0).dt.total_seconds()/86400.0
ω      = 2*np.pi/365.25
df['sin1'] = np.sin(ω*df['t_days'])
df['cos1'] = np.cos(ω*df['t_days'])
p1_std = (df['p1']-df['p1'].mean())/df['p1'].std()
p2_std = (df['p2']-df['p2'].mean())/df['p2'].std()

sin_t, cos_t = df['sin1'].values, df['cos1'].values

# LS blocks
A_CE = np.column_stack([np.ones_like(p2_std), p2_std, sin_t, cos_t])
x_CE,*_ = np.linalg.lstsq(A_CE, df['r_CE'], rcond=None)
x_EC,*_ = np.linalg.lstsq(A_CE, df['r_EC'], rcond=None)
r_CE_lin, r_EC_lin = A_CE@x_CE, A_CE@x_EC

A_CW = np.column_stack([np.ones_like(p1_std), p1_std, sin_t, cos_t])
x_CW,*_ = np.linalg.lstsq(A_CW, df['r_CW'], rcond=None)
x_WC,*_ = np.linalg.lstsq(A_CW, df['r_WC'], rcond=None)
r_CW_lin, r_WC_lin = A_CW@x_CW, A_CW@x_WC

A_EW = np.column_stack([np.ones_like(p1_std), p1_std, p2_std, sin_t, cos_t])
x_EW,*_ = np.linalg.lstsq(A_EW, df['r_EW'], rcond=None)
x_WE,*_ = np.linalg.lstsq(A_EW, df['r_WE'], rcond=None)
r_EW_lin, r_WE_lin = A_EW@x_EW, A_EW@x_WE

R_lin = np.column_stack([r_WE_lin,r_EW_lin,r_WC_lin,r_CW_lin,r_CE_lin,r_EC_lin]).astype('float32')
R_obs = df[Y_cols].values.astype('float32')
R_resid = R_obs - R_lin

# 2) BUILD FEATURE MATRIX + LS inputs
df_feat = pd.DataFrame({
    'p1':df['p1'],'p2':df['p2'],'p3':df['p3'],
    't_days':df['t_days'],'sin1':df['sin1'],'cos1':df['cos1']
})
for lag in (1,2,3):
    df_feat[f'p1_l{lag}'] = df['p1'].shift(lag)
    df_feat[f'p2_l{lag}'] = df['p2'].shift(lag)
    df_feat[f'p3_l{lag}'] = df['p3'].shift(lag)
for col, arr in zip(
    ['r_WE_lin','r_EW_lin','r_WC_lin','r_CW_lin','r_CE_lin','r_EC_lin'],
    [r_WE_lin, r_EW_lin, r_WC_lin, r_CW_lin, r_CE_lin, r_EC_lin]
):
    df_feat[col] = arr
df_feat.dropna(inplace=True)
df_feat.reset_index(drop=True, inplace=True)

idx = df_feat.index.values
X_raw         = df_feat.values.astype('float32')
R_resid_true  = R_resid[idx]
R_lin_full    = R_lin[idx]
R_true_full   = R_obs[idx]
times_full    = df['time'].values[idx]

# 3) SCALE
scaler_X = StandardScaler().fit(X_raw)
Xs       = scaler_X.transform(X_raw)
scaler_R = StandardScaler().fit(R_resid_true)
Rs_scaled= scaler_R.transform(R_resid_true)
mean_R   = K.constant(scaler_R.mean_.reshape((1,6)), dtype='float32')
scale_R  = K.constant(scaler_R.scale_.reshape((1,6)), dtype='float32')

# 4) TRAIN ON LAST 70%
N = Xs.shape[0]
start = int(0.30*N)
X_train = Xs[start:]
R_train = Rs_scaled[start:]

# 5) DEFINE 3-HEAD PINN
inp = layers.Input(shape=(Xs.shape[1],))
shared = layers.Dense(64,activation='relu')(inp)
shared = layers.Dense(64,activation='relu')(shared)

cols = df_feat.columns.tolist()
def gather(idxs):
    return layers.Lambda(lambda x: tf.gather(x, idxs, axis=1))(inp)

east = gather([cols.index('r_CE_lin'), cols.index('r_EC_lin')])
west = gather([cols.index('r_CW_lin'), cols.index('r_WC_lin')])
mid  = gather([cols.index('r_WE_lin'), cols.index('r_EW_lin')])

def head_block(x_feat):
    xh = layers.Concatenate()([shared, x_feat])
    xh = layers.Dense(32,activation='relu')(xh)
    return layers.Dense(2)(xh)

r_CE_p, r_EC_p = tf.split(head_block(east),2,axis=1)
r_CW_p, r_WC_p = tf.split(head_block(west),2,axis=1)
r_WE_p, r_EW_p = tf.split(head_block(mid),2,axis=1)
resid_out = layers.Concatenate()([r_WE_p, r_EW_p, r_WC_p, r_CW_p, r_CE_p, r_EC_p])

model = Model(inp, resid_out)

# 6) STRICT HINGE LOSS
def loss_fn(r_true_s, r_pred_s):
    r_true_m = r_true_s*scale_R + mean_R
    r_pred_m = r_pred_s*scale_R + mean_R
    Lm = K.mean(K.square(r_true_s - r_pred_s))
    CE, EC = r_pred_s[:,4], r_pred_s[:,5]
    CW, WC = r_pred_s[:,3], r_pred_s[:,2]
    Ls = K.mean(K.square(CE-EC)+K.square(CW-WC))
    dCE = CE[1:]-CE[:-1]; dCW = CW[1:]-CW[:-1]
    dEW = r_pred_s[1:,1]-r_pred_s[:-1,1]
    Lc = K.mean(K.square(dCE + dCW - dEW))
    delta = K.square(r_true_m - r_pred_m) - K.square(r_true_m)
    Lh = K.mean(K.maximum(delta,0.0))
    return 1.0*Lm + 0.1*Ls + 0.1*Lc + 10.0*Lh

model.compile(optimizer='adam', loss=loss_fn)

# 7) TRAIN
es = callbacks.EarlyStopping(monitor='loss', patience=30, restore_best_weights=True)
model.fit(X_train, R_train, epochs=300, batch_size=len(X_train), callbacks=[es], verbose=1)

# 8) PREDICT & RECONSTRUCT FULL
Rs_pred_s   = model.predict(Xs)
Rs_pred     = scaler_R.inverse_transform(Rs_pred_s)
R_pred_full = R_lin_full + Rs_pred

# 9) EVALUATE
print("LS-only metrics:")
for i,name in enumerate(Y_cols):
    print(f"{name}: R²={r2_score(R_true_full[:,i], R_lin_full[:,i]):.3f}, RMSE={mean_squared_error(R_true_full[:,i], R_lin_full[:,i], squared=False):.3f}")
print("\nHybrid 3-head PINN metrics:")
for i,name in enumerate(Y_cols):
    print(f"{name}: R²={r2_score(R_true_full[:,i], R_pred_full[:,i]):.3f}, RMSE={mean_squared_error(R_true_full[:,i], R_pred_full[:,i], squared=False):.3f}")
# Out:
# Epoch 1/300
# 1/1 [==============================] - 1s 1s/step - loss: 6.5186
# Epoch 2/300
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3169
# Epoch 3/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.3190
# Epoch 4/300
# 1/1 [==============================] - 0s 7ms/step - loss: 3.5125
# Epoch 5/300
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8583
# Epoch 6/300
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3577
# Epoch 7/300
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0354
# Epoch 8/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8574
# Epoch 9/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7568
# Epoch 10/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6785
# Epoch 11/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.
300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4766
# Epoch 263/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4750
# Epoch 264/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4733
# Epoch 265/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4703
# Epoch 266/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4689
# Epoch 267/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4685
# Epoch 268/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4654
# Epoch 269/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4636
# Epoch 270/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4613
# Epoch 271/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4601
# Epoch 272/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4581
# Epoch 273/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4558
# Epoch 274/300
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4565
# Epoch 275/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4524
# Epoch 276/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4513
# Epoch 277/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4495
# Epoch 278/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4486
# Epoch 279/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4451
# Epoch 280/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4446
# Epoch 281/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4429
# Epoch 282/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4408
# Epoch 283/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4394
# Epoch 284/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4375
# Epoch 285/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4365
# Epoch 286/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4338
# Epoch 287/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4322
# Epoch 288/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4307
# Epoch 289/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4294
# Epoch 290/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4271
# Epoch 291/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4258
# Epoch 292/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4239
# Epoch 293/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4229
# Epoch 294/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4200
# Epoch 295/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4193
# Epoch 296/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4180
# Epoch 297/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4164
# Epoch 298/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4145
# Epoch 299/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4125
# Epoch 300/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4101
# 136/136 [==============================] - 0s 866us/step
# LS-only metrics:
# r_WE: R²=0.827, RMSE=1.221
# r_EW: R²=0.742, RMSE=1.707
# r_WC: R²=0.546, RMSE=0.820
# r_CW: R²=0.576, RMSE=0.957
# r_CE: R²=0.884, RMSE=0.767
# r_EC: R²=0.852, RMSE=0.871
#
# Hybrid 3-head PINN metrics:
# r_WE: R²=0.834, RMSE=1.196
# r_EW: R²=0.800, RMSE=1.503
# r_WC: R²=0.669, RMSE=0.700
# r_CW: R²=0.650, RMSE=0.869
# r_CE: R²=0.930, RMSE=0.598
# r_EC: R²=0.911, RMSE=0.677

# %%
# 10) PLOT
for i,name in enumerate(Y_cols):
    fig, ax = plt.subplots(figsize=(10,4), tight_layout=True)
    ax.plot(times_full, R_true_full[:,i], label='Obs', lw=2)
    ax.plot(times_full, R_lin_full[:,i],  label='LS-only', ls='--', lw=2)
    ax.plot(times_full, R_pred_full[:,i], label='Hybrid PINN', lw=1)
    ax.set_title(f"{name}: LS R²={r2_score(R_true_full[:,i], R_lin_full[:,i]):.3f}, Hybrid R²={r2_score(R_true_full[:,i], R_pred_full[:,i]):.3f}")
    ax.legend(); ax.set_ylabel("Range (m)")
    plt.show()

# %%
import os
# -----------------------------------------------------------------------------
# FORCE CPU PARALLELISM TO 48 CORES
# -----------------------------------------------------------------------------
os.environ["OMP_NUM_THREADS"]      = "48"
os.environ["MKL_NUM_THREADS"]      = "48"
os.environ["OPENBLAS_NUM_THREADS"] = "48"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib, pathlib

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error

import tensorflow as tf
from tensorflow.keras import layers, Model, backend as K, callbacks

# configure TensorFlow threading
tf.config.threading.set_intra_op_parallelism_threads(48)
tf.config.threading.set_inter_op_parallelism_threads(48)

# =============================================================================
# FINAL TRAINING WITH BEST HYPERPARAMETERS (LAST 70% TRAIN, EVALUATE FULL SERIES)
# =============================================================================

# 0) LOAD & FILTER DATA
df_var = df_var.dropna().reset_index(drop=True)
df_var['Record Time'] = pd.to_datetime(df_var['Record Time'], utc=True)
df_var = df_var[df_var['Record Time'] >= pd.Timestamp(2022,9,7,tz='UTC')].reset_index(drop=True)

df = pd.DataFrame({
    'time': df_var['Record Time'],
    'p1':   df_var['p1'],  'p2': df_var['p2'],  'p3': df_var['p3'],
    'r_WE': df_var['d1'],  'r_EW': df_var['d2'],  'r_EC': df_var['d3'],
    'r_CE': df_var['d4'],  'r_WC': df_var['d5'],  'r_CW': df_var['d6'],
})
Y_cols = ['r_WE','r_EW','r_WC','r_CW','r_CE','r_EC']

# 1) TIME & SEASONAL FEATURES + STANDARDIZED PRESSURES
t0 = df['time'].min()
df['t_days'] = (df['time'] - t0).dt.total_seconds() / 86400.0
ω = 2 * np.pi / 365.25
df['sin1'] = np.sin(ω * df['t_days'])
df['cos1'] = np.cos(ω * df['t_days'])

p1_std = (df['p1'] - df['p1'].mean()) / df['p1'].std()
p2_std = (df['p2'] - df['p2'].mean()) / df['p2'].std()
sin_t, cos_t = df['sin1'].values, df['cos1'].values

# 2) LEAST-SQUARES BLOCKS
A_CE = np.column_stack([np.ones_like(p2_std), p2_std, sin_t, cos_t])
x_CE,*_ = np.linalg.lstsq(A_CE, df['r_CE'], rcond=None)
x_EC,*_ = np.linalg.lstsq(A_CE, df['r_EC'], rcond=None)
r_CE_lin, r_EC_lin = A_CE @ x_CE, A_CE @ x_EC

A_CW = np.column_stack([np.ones_like(p1_std), p1_std, sin_t, cos_t])
x_CW,*_ = np.linalg.lstsq(A_CW, df['r_CW'], rcond=None)
x_WC,*_ = np.linalg.lstsq(A_CW, df['r_WC'], rcond=None)
r_CW_lin, r_WC_lin = A_CW @ x_CW, A_CW @ x_WC

A_EW = np.column_stack([np.ones_like(p1_std), p1_std, p2_std, sin_t, cos_t])
x_EW,*_ = np.linalg.lstsq(A_EW, df['r_EW'], rcond=None)
x_WE,*_ = np.linalg.lstsq(A_EW, df['r_WE'], rcond=None)
r_EW_lin, r_WE_lin = A_EW @ x_EW, A_EW @ x_WE

R_lin = np.column_stack([
    r_WE_lin, r_EW_lin, r_WC_lin,
    r_CW_lin, r_CE_lin, r_EC_lin
]).astype('float32')
R_obs   = df[Y_cols].values.astype('float32')
R_resid = (R_obs - R_lin).astype('float32')

# 3) FEATURE MATRIX + LAGS + LS FEATURES
df_feat = df[['p1','p2','p3','t_days','sin1','cos1']].copy()
for lag in (1,2,3):
    df_feat[f'p1_l{lag}'] = df['p1'].shift(lag)
    df_feat[f'p2_l{lag}'] = df['p2'].shift(lag)
    df_feat[f'p3_l{lag}'] = df['p3'].shift(lag)

ls_cols = ['r_WE_lin','r_EW_lin','r_WC_lin','r_CW_lin','r_CE_lin','r_EC_lin']
ls_vals = [r_WE_lin, r_EW_lin, r_WC_lin, r_CW_lin, r_CE_lin, r_EC_lin]
for col, arr in zip(ls_cols, ls_vals):
    df_feat[col] = arr

df_feat.dropna(inplace=True)
df_feat.reset_index(drop=True, inplace=True)

idx = df_feat.index.values
X_raw         = df_feat.values.astype('float32')
R_resid_true  = R_resid[idx]
R_lin_aligned = R_lin[idx]
R_true_aligned= R_obs[idx]
times_aligned = df['time'].values[idx]

# 4) SCALE & TRAIN/VAL SPLIT (last 70% train)
scaler_X = StandardScaler().fit(X_raw)
Xs       = scaler_X.transform(X_raw)
scaler_R = StandardScaler().fit(R_resid_true)
Rs_s     = scaler_R.transform(R_resid_true)

N = Xs.shape[0]
start = int(0.30 * N)
X_train   = Xs[start:]
Rs_train  = Rs_s[start:]

mean_R = K.constant(scaler_R.mean_.reshape((1,6)), dtype='float32')
scale_R= K.constant(scaler_R.scale_.reshape((1,6)), dtype='float32')

# indices for LS features
feat_cols = df_feat.columns.tolist()
i_CE, i_EC = feat_cols.index('r_CE_lin'), feat_cols.index('r_EC_lin')
i_CW, i_WC = feat_cols.index('r_CW_lin'), feat_cols.index('r_WC_lin')
i_WE, i_EW = feat_cols.index('r_WE_lin'), feat_cols.index('r_EW_lin')

# 5) BUILD & TRAIN FINAL 3-HEAD PINN
w_mse, w_sym, w_clo, w_hinge = 10.0, 0.5, 0.01, 5.0

inp = layers.Input(shape=(Xs.shape[1],))
shared = layers.Dense(64,activation='relu')(inp)
shared = layers.Dense(64,activation='relu')(shared)

east = layers.Lambda(lambda x: tf.gather(x,[i_CE,i_EC],axis=1))(inp)
west = layers.Lambda(lambda x: tf.gather(x,[i_CW,i_WC],axis=1))(inp)
mid  = layers.Lambda(lambda x: tf.gather(x,[i_WE,i_EW],axis=1))(inp)

def head_block(xf):
    xh = layers.Concatenate()([shared, xf])
    xh = layers.Dense(32,activation='relu')(xh)
    return layers.Dense(2)(xh)

r_CE_p, r_EC_p = tf.split(head_block(east),2,axis=1)
r_CW_p, r_WC_p = tf.split(head_block(west),2,axis=1)
r_WE_p, r_EW_p = tf.split(head_block(mid),2,axis=1)

resid_out = layers.Concatenate()([
    r_WE_p, r_EW_p, r_WC_p, r_CW_p, r_CE_p, r_EC_p
])
model = Model(inp, resid_out)

def loss_fn(r_true_s, r_pred_s):
    r_true_m = r_true_s*scale_R + mean_R
    r_pred_m = r_pred_s*scale_R + mean_R
    Lm   = K.mean(K.square(r_true_s - r_pred_s))
    CE,EC= r_pred_s[:,4], r_pred_s[:,5]
    CW,WC= r_pred_s[:,3], r_pred_s[:,2]
    Ls   = K.mean(K.square(CE-EC)+K.square(CW-WC))
    dCE  = CE[1:]-CE[:-1]; dCW= CW[1:]-CW[:-1]
    dEW  = r_pred_s[1:,1]-r_pred_s[:-1,1]
    Lc   = K.mean(K.square(dCE + dCW - dEW))
    delta= K.square(r_true_m-r_pred_m)-K.square(r_true_m)
    Lh   = K.mean(K.maximum(delta,0.0))
    return w_mse*Lm + w_sym*Ls + w_clo*Lc + w_hinge*Lh

model.compile(optimizer='adam', loss=loss_fn)
es = callbacks.EarlyStopping(monitor='loss',patience=30,restore_best_weights=True)
model.fit(X_train, Rs_train, epochs=300, batch_size=len(X_train), callbacks=[es], verbose=1)

# 6) PREDICT & RECONSTRUCT FULL SERIES
Rs_pred_s   = model.predict(Xs)
Rs_pred     = scaler_R.inverse_transform(Rs_pred_s)
R_pred_full = R_lin_aligned + Rs_pred

# 7) EVALUATE FINAL METRICS
print("LS-only metrics:")
for i,name in enumerate(Y_cols):
    r2_lin = r2_score(R_true_aligned[:,i], R_lin_aligned[:,i])
    rmse_lin = mean_squared_error(R_true_aligned[:,i], R_lin_aligned[:,i], squared=False)
    print(f"{name}: R²={r2_lin:.3f}, RMSE={rmse_lin:.3f} m")

print("\nHybrid PINN (final) metrics:")
for i,name in enumerate(Y_cols):
    r2_h = r2_score(R_true_aligned[:,i], R_pred_full[:,i])
    rmse_h = mean_squared_error(R_true_aligned[:,i], R_pred_full[:,i], squared=False)
    print(f"{name}: R²={r2_h:.3f}, RMSE={rmse_h:.3f} m")
# Out:
# Epoch 1/300
# 1/1 [==============================] - 1s 1s/step - loss: 14.2706
# Epoch 2/300
# 1/1 [==============================] - 0s 8ms/step - loss: 12.6822
# Epoch 3/300
# 1/1 [==============================] - 0s 8ms/step - loss: 11.5621
# Epoch 4/300
# 1/1 [==============================] - 0s 7ms/step - loss: 10.8113
# Epoch 5/300
# 1/1 [==============================] - 0s 8ms/step - loss: 10.3057
# Epoch 6/300
# 1/1 [==============================] - 0s 7ms/step - loss: 9.9440
# Epoch 7/300
# 1/1 [==============================] - 0s 7ms/step - loss: 9.6701
# Epoch 8/300
# 1/1 [==============================] - 0s 7ms/step - loss: 9.5044
# Epoch 9/300
# 1/1 [==============================] - 0s 8ms/step - loss: 9.3799
# Epoch 10/300
# 1/1 [==============================] - 0s 8ms/step - loss: 9.2526
# Epoch 11/300
# 1/1 [==============================] - 0s 7ms/step - loss: 9.1220
# Epoch 12/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.9927
# Epoch 13/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.8693
# Epoch 14/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.7528
# Epoch 15/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.6438
# Epoch 16/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.5472
# Epoch 17/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.4618
# Epoch 18/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.3822
# Epoch 19/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.3038
# Epoch 20/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.2246
# Epoch 21/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.1433
# Epoch 22/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.0610
# Epoch 23/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.9778
# Epoch 24/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.8952
# Epoch 25/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.8152
# Epoch 26/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.7398
# Epoch 27/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.6694
# Epoch 28/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.6039
# Epoch 29/300
# 1/1 [==============================] - 0s 8ms/step - loss: 7.5421
# Epoch 30/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4823
# Epoch 31/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4232
# Epoch 32/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.3625
# Epoch 33/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.2997
# Epoch 34/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.2353
# Epoch 35/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.1702
# Epoch 36/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.1061
# Epoch 37/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.0437
# Epoch 38/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9834
# Epoch 39/300
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9249
# Epoch 40/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8684
# Epoch 41/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8122
# Epoch 42/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7551
# Epoch 43/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.6978
# Epoch 44/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.6405
# Epoch 45/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.5837
# Epoch 46/300
# 1/1 [==============================] - 0s 9ms/step - loss: 6.5278
# Epoch 47/300
# 1/1 [==============================] - 0s 8ms/step - loss: 6.4723
# Epoch 48/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.4174
# Epoch 49/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3627
# Epoch 50/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3080
# Epoch 51/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.2535
# Epoch 52/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1989
# Epoch 53/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1440
# Epoch 54/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.0887
# Epoch 55/300
# 1/1 [==============================] - 0s 7ms/step - loss: 6.0335
# Epoch 56/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.9786
# Epoch 57/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.9236
# Epoch 58/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.8690
# Epoch 59/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.8141
# Epoch 60/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.7590
# Epoch 61/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.7043
# Epoch 62/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.6497
# Epoch 63/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.5955
# Epoch 64/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.5413
# Epoch 65/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4876
# Epoch 66/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4335
# Epoch 67/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3789
# Epoch 68/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3253
# Epoch 69/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2736
# Epoch 70/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2221
# Epoch 71/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1700
# Epoch 72/300
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1184
# Epoch 73/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0661
# Epoch 74/300
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0138
# Epoch 75/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9616
# Epoch 76/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9095
# Epoch 77/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8567
# Epoch 78/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8043
# Epoch 79/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7517
# Epoch 80/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6997
# Epoch 81/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6473
# Epoch 82/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5951
# Epoch 83/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5425
# Epoch 84/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.4892
# Epoch 85/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.4363
# Epoch 86/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3838
# Epoch 87/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3315
# Epoch 88/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2792
# Epoch 89/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2271
# Epoch 90/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1751
# Epoch 91/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1234
# Epoch 92/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.
300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3945
# Epoch 214/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3862
# Epoch 215/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3786
# Epoch 216/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3728
# Epoch 217/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3661
# Epoch 218/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3591
# Epoch 219/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3517
# Epoch 220/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3448
# Epoch 221/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3376
# Epoch 222/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3314
# Epoch 223/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3248
# Epoch 224/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3182
# Epoch 225/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3110
# Epoch 226/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3042
# Epoch 227/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2986
# Epoch 228/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2928
# Epoch 229/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2856
# Epoch 230/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2789
# Epoch 231/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2731
# Epoch 232/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2671
# Epoch 233/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2606
# Epoch 234/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2554
# Epoch 235/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2488
# Epoch 236/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2440
# Epoch 237/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2384
# Epoch 238/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2331
# Epoch 239/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2269
# Epoch 240/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2212
# Epoch 241/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2167
# Epoch 242/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2104
# Epoch 243/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2046
# Epoch 244/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1998
# Epoch 245/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1938
# Epoch 246/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1891
# Epoch 247/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1849
# Epoch 248/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1798
# Epoch 249/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1753
# Epoch 250/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1728
# Epoch 251/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1708
# Epoch 252/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1679
# Epoch 253/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1607
# Epoch 254/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1503
# Epoch 255/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1457
# Epoch 256/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1446
# Epoch 257/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1410
# Epoch 258/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1339
# Epoch 259/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1272
# Epoch 260/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1240
# Epoch 261/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1224
# Epoch 262/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1162
# Epoch 263/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1106
# Epoch 264/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1071
# Epoch 265/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1037
# Epoch 266/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0994
# Epoch 267/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0936
# Epoch 268/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0897
# Epoch 269/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0865
# Epoch 270/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0830
# Epoch 271/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0784
# Epoch 272/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0739
# Epoch 273/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0698
# Epoch 274/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0676
# Epoch 275/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0643
# Epoch 276/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0599
# Epoch 277/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0552
# Epoch 278/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0514
# Epoch 279/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0484
# Epoch 280/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0447
# Epoch 281/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0412
# Epoch 282/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0362
# Epoch 283/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0337
# Epoch 284/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0300
# Epoch 285/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0276
# Epoch 286/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0238
# Epoch 287/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0194
# Epoch 288/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0162
# Epoch 289/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0130
# Epoch 290/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0101
# Epoch 291/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0059
# Epoch 292/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0033
# Epoch 293/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9992
# Epoch 294/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9971
# Epoch 295/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9938
# Epoch 296/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9909
# Epoch 297/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9880
# Epoch 298/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9851
# Epoch 299/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9830
# Epoch 300/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9803
# 136/136 [==============================] - 0s 846us/step
# LS-only metrics:
# r_WE: R²=0.827, RMSE=1.221 m
# r_EW: R²=0.742, RMSE=1.707 m
# r_WC: R²=0.546, RMSE=0.820 m
# r_CW: R²=0.576, RMSE=0.957 m
# r_CE: R²=0.884, RMSE=0.767 m
# r_EC: R²=0.852, RMSE=0.871 m
#
# Hybrid PINN (final) metrics:
# r_WE: R²=0.935, RMSE=0.749 m
# r_EW: R²=0.935, RMSE=0.855 m
# r_WC: R²=0.564, RMSE=0.803 m
# r_CW: R²=0.019, RMSE=1.456 m
# r_CE: R²=0.962, RMSE=0.439 m
# r_EC: R²=0.943, RMSE=0.539 m

# %%
# 8) PLOT RESULTS
for i,name in enumerate(Y_cols):
    fig, ax = plt.subplots(figsize=(10,4), tight_layout=True)
    ax.plot(times_aligned,  R_true_aligned[:,i], label='Obs', lw=2)
    ax.plot(times_aligned,  R_lin_aligned[:,i],  label='LS-only', ls='--', lw=2)
    ax.plot(times_aligned,  R_pred_full[:,i],   label='Hybrid PINN', lw=1)
    ax.set_title(f"{name}: LS R²={r2_score(R_true_aligned[:,i], R_lin_aligned[:,i]):.3f}, "
                 f"PINN R²={r2_score(R_true_aligned[:,i], R_pred_full[:,i]):.3f}")
    ax.legend(); ax.set_ylabel("Range (m)")
    plt.show()

# %%
import os
# -----------------------------------------------------------------------------
# FORCE CPU PARALLELISM TO 48 CORES
# -----------------------------------------------------------------------------
os.environ["OMP_NUM_THREADS"]      = "48"
os.environ["MKL_NUM_THREADS"]      = "48"
os.environ["OPENBLAS_NUM_THREADS"] = "48"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib, pathlib

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error

import tensorflow as tf
from tensorflow.keras import layers, Model, backend as K, callbacks

# configure TensorFlow threading
tf.config.threading.set_intra_op_parallelism_threads(48)
tf.config.threading.set_inter_op_parallelism_threads(48)

# =============================================================================
# FINAL TRAINING WITH ABSOLUTE-ERROR HINGE LOSS
# ‑ TRAIN ON LAST 70% – EVALUATE FULL SERIES
# =============================================================================

# 0) LOAD & FILTER
df_var = df_var.dropna().reset_index(drop=True)
df_var['Record Time'] = pd.to_datetime(df_var['Record Time'], utc=True)
df_var = df_var[df_var['Record Time'] >= pd.Timestamp(2022,9,7,tz='UTC')].reset_index(drop=True)

df = pd.DataFrame({
    'time': df_var['Record Time'],
    'p1':   df_var['p1'],  'p2': df_var['p2'],  'p3': df_var['p3'],
    'r_WE': df_var['d1'],  'r_EW': df_var['d2'],  'r_EC': df_var['d3'],
    'r_CE': df_var['d4'],  'r_WC': df_var['d5'],  'r_CW': df_var['d6'],
})
Y_cols = ['r_WE','r_EW','r_WC','r_CW','r_CE','r_EC']

# 1) TIME & SEASON + STANDARDIZED PRESSURES
t0 = df['time'].min()
df['t_days'] = (df['time'] - t0).dt.total_seconds() / 86400.0
ω = 2 * np.pi / 365.25
df['sin1'] = np.sin(ω * df['t_days'])
df['cos1'] = np.cos(ω * df['t_days'])

p1_std = (df['p1'] - df['p1'].mean()) / df['p1'].std()
p2_std = (df['p2'] - df['p2'].mean()) / df['p2'].std()
sin_t, cos_t = df['sin1'].values, df['cos1'].values

# 2) LEAST-SQUARES BLOCKS
A_CE = np.column_stack([np.ones_like(p2_std), p2_std, sin_t, cos_t])
x_CE,*_ = np.linalg.lstsq(A_CE, df['r_CE'], rcond=None)
x_EC,*_ = np.linalg.lstsq(A_CE, df['r_EC'], rcond=None)
r_CE_lin, r_EC_lin = A_CE @ x_CE, A_CE @ x_EC

A_CW = np.column_stack([np.ones_like(p1_std), p1_std, sin_t, cos_t])
x_CW,*_ = np.linalg.lstsq(A_CW, df['r_CW'], rcond=None)
x_WC,*_ = np.linalg.lstsq(A_CW, df['r_WC'], rcond=None)
r_CW_lin, r_WC_lin = A_CW @ x_CW, A_CW @ x_WC

A_EW = np.column_stack([np.ones_like(p1_std), p1_std, p2_std, sin_t, cos_t])
x_EW,*_ = np.linalg.lstsq(A_EW, df['r_EW'], rcond=None)
x_WE,*_ = np.linalg.lstsq(A_EW, df['r_WE'], rcond=None)
r_EW_lin, r_WE_lin = A_EW @ x_EW, A_EW @ x_WE

R_lin        = np.column_stack([r_WE_lin, r_EW_lin, r_WC_lin, r_CW_lin, r_CE_lin, r_EC_lin]).astype('float32')
R_obs        = df[Y_cols].values.astype('float32')
R_resid_full = (R_obs - R_lin).astype('float32')

# 3) FEATURE MATRIX + LAGS + LS FEATURES
df_feat = pd.DataFrame({
    'p1': df['p1'], 'p2': df['p2'], 'p3': df['p3'],
    't_days': df['t_days'], 'sin1': df['sin1'], 'cos1': df['cos1']
})
for lag in (1,2,3):
    df_feat[f'p1_l{lag}'] = df['p1'].shift(lag)
    df_feat[f'p2_l{lag}'] = df['p2'].shift(lag)
    df_feat[f'p3_l{lag}'] = df['p3'].shift(lag)
for col, arr in zip(['r_WE_lin','r_EW_lin','r_WC_lin','r_CW_lin','r_CE_lin','r_EC_lin'],
                    [r_WE_lin, r_EW_lin, r_WC_lin, r_CW_lin, r_CE_lin, r_EC_lin]):
    df_feat[col] = arr

df_feat.dropna(inplace=True)
df_feat.reset_index(drop=True, inplace=True)

idx            = df_feat.index.values
X_raw          = df_feat.values.astype('float32')
R_resid_aligned = R_resid_full[idx]
R_lin_aligned  = R_lin[idx]
R_true_aligned = R_obs[idx]
times_aligned  = df['time'].values[idx]

# 4) SCALE & SPLIT LAST 70%
scaler_X = StandardScaler().fit(X_raw)
Xs       = scaler_X.transform(X_raw)
scaler_R = StandardScaler().fit(R_resid_aligned)
Rs_s     = scaler_R.transform(R_resid_aligned)

N       = Xs.shape[0]
start   = int(0.30 * N)
X_train = Xs[start:]
Rs_train= Rs_s[start:]

# constants for un-scaling
mean_R  = K.constant(scaler_R.mean_.reshape((1,6)), dtype='float32')
scale_R = K.constant(scaler_R.scale_.reshape((1,6)), dtype='float32')

# indices for LS features per head
feat_cols = df_feat.columns.tolist()
i_CE, i_EC = feat_cols.index('r_CE_lin'), feat_cols.index('r_EC_lin')
i_CW, i_WC = feat_cols.index('r_CW_lin'), feat_cols.index('r_WC_lin')
i_WE, i_EW = feat_cols.index('r_WE_lin'), feat_cols.index('r_EW_lin')

# 5) BUILD 3-HEAD PINN RESIDUAL MODEL
w_mse, w_sym, w_clo, w_hinge = 10.0, 0.5, 0.01, 5.0

inp    = layers.Input(shape=(Xs.shape[1],))
shared = layers.Dense(64, activation='relu')(inp)
shared = layers.Dense(64, activation='relu')(shared)

east = layers.Lambda(lambda x: tf.gather(x, [i_CE, i_EC], axis=1))(inp)
west = layers.Lambda(lambda x: tf.gather(x, [i_CW, i_WC], axis=1))(inp)
mid  = layers.Lambda(lambda x: tf.gather(x, [i_WE, i_EW], axis=1))(inp)

def head_block(xf):
    xh = layers.Concatenate()([shared, xf])
    xh = layers.Dense(32, activation='relu')(xh)
    return layers.Dense(2)(xh)

r_CE_p, r_EC_p = tf.split(head_block(east), 2, axis=1)
r_CW_p, r_WC_p = tf.split(head_block(west), 2, axis=1)
r_WE_p, r_EW_p = tf.split(head_block(mid), 2, axis=1)

resid_out = layers.Concatenate()([
    r_WE_p, r_EW_p,
    r_WC_p, r_CW_p,
    r_CE_p, r_EC_p
])
model = Model(inp, resid_out)

# 6) LOSS WITH ABSOLUTE-ERROR HINGE
def loss_fn(r_true_s, r_pred_s):
    # back to meter-scale errors
    e_ls     = r_true_s * scale_R + mean_R
    pred_res = r_pred_s * scale_R + mean_R
    e_hybrid = e_ls - pred_res

    # MSE on scaled residuals
    L_mse  = K.mean(K.square(r_true_s - r_pred_s))
    # symmetry
    CE, EC = r_pred_s[:,4], r_pred_s[:,5]
    CW, WC = r_pred_s[:,3], r_pred_s[:,2]
    L_sym  = K.mean(K.square(CE - EC) + K.square(CW - WC))
    # derivative closure
    dCE = CE[1:] - CE[:-1]; dCW = CW[1:] - CW[:-1]
    dEW = r_pred_s[1:,1] - r_pred_s[:-1,1]
    L_clo = K.mean(K.square(dCE + dCW - dEW))

    # absolute-error hinge
    delta = K.abs(e_hybrid) - K.abs(e_ls)
    L_hinge = K.mean(K.maximum(delta, 0.0))

    return (w_mse * L_mse
          + w_sym * L_sym
          + w_clo * L_clo
          + w_hinge * L_hinge)

model.compile(optimizer='adam', loss=loss_fn)
es = callbacks.EarlyStopping(monitor='loss', patience=30, restore_best_weights=True)

# 7) TRAIN ON LAST 70%
model.fit(X_train, Rs_train, epochs=300, batch_size=len(X_train),
          callbacks=[es], verbose=1)

# 8) PREDICT & RECONSTRUCT FULL SERIES
Rs_pred_s   = model.predict(Xs)
Rs_pred     = scaler_R.inverse_transform(Rs_pred_s)
R_pred_full = R_lin_aligned + Rs_pred

# 9) EVALUATE & PRINT METRICS
print("LS-only metrics:")
for i, name in enumerate(Y_cols):
    r2_lin  = r2_score(R_true_aligned[:,i], R_lin_aligned[:,i])
    rmse_lin= mean_squared_error(R_true_aligned[:,i], R_lin_aligned[:,i], squared=False)
    print(f"{name}: R²={r2_lin:.3f}, RMSE={rmse_lin:.3f} m")

print("\nHybrid PINN (absolute-hinge) metrics:")
for i, name in enumerate(Y_cols):
    r2_h   = r2_score(R_true_aligned[:,i], R_pred_full[:,i])
    rmse_h = mean_squared_error(R_true_aligned[:,i], R_pred_full[:,i], squared=False)
    print(f"{name}: R²={r2_h:.3f}, RMSE={rmse_h:.3f} m")
# Out:
# Epoch 1/300
# 1/1 [==============================] - 1s 1s/step - loss: 16.8493
# Epoch 2/300
# 1/1 [==============================] - 0s 8ms/step - loss: 15.2556
# Epoch 3/300
# 1/1 [==============================] - 0s 7ms/step - loss: 13.9236
# Epoch 4/300
# 1/1 [==============================] - 0s 8ms/step - loss: 12.8323
# Epoch 5/300
# 1/1 [==============================] - 0s 7ms/step - loss: 11.9551
# Epoch 6/300
# 1/1 [==============================] - 0s 7ms/step - loss: 11.2467
# Epoch 7/300
# 1/1 [==============================] - 0s 7ms/step - loss: 10.6776
# Epoch 8/300
# 1/1 [==============================] - 0s 7ms/step - loss: 10.2242
# Epoch 9/300
# 1/1 [==============================] - 0s 7ms/step - loss: 9.8617
# Epoch 10/300
# 1/1 [==============================] - 0s 8ms/step - loss: 9.5692
# Epoch 11/300
# 1/1 [==============================] - 0s 7ms/step - loss: 9.3383
# Epoch 12/300
# 1/1 [==============================] - 0s 7ms/step - loss: 9.1567
# Epoch 13/300
# 1/1 [==============================] - 0s 7ms/step - loss: 9.0062
# Epoch 14/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.8724
# Epoch 15/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.7483
# Epoch 16/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.6362
# Epoch 17/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.5352
# Epoch 18/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.4434
# Epoch 19/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.3563
# Epoch 20/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.2711
# Epoch 21/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.1868
# Epoch 22/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.1044
# Epoch 23/300
# 1/1 [==============================] - 0s 7ms/step - loss: 8.0243
# Epoch 24/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.9463
# Epoch 25/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.8706
# Epoch 26/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.7968
# Epoch 27/300
# 1/1 [==============================] - 0s 7ms/step - loss: 7.
300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0859
# Epoch 274/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0822
# Epoch 275/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0776
# Epoch 276/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0743
# Epoch 277/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0691
# Epoch 278/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0653
# Epoch 279/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0615
# Epoch 280/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0560
# Epoch 281/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0503
# Epoch 282/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0456
# Epoch 283/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0425
# Epoch 284/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0384
# Epoch 285/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0365
# Epoch 286/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0314
# Epoch 287/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0277
# Epoch 288/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0228
# Epoch 289/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0187
# Epoch 290/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0155
# Epoch 291/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0103
# Epoch 292/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0081
# Epoch 293/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0032
# Epoch 294/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0005
# Epoch 295/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9968
# Epoch 296/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9924
# Epoch 297/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9888
# Epoch 298/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9857
# Epoch 299/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9820
# Epoch 300/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9790
# 136/136 [==============================] - 0s 861us/step
# LS-only metrics:
# r_WE: R²=0.827, RMSE=1.221 m
# r_EW: R²=0.742, RMSE=1.707 m
# r_WC: R²=0.546, RMSE=0.820 m
# r_CW: R²=0.576, RMSE=0.957 m
# r_CE: R²=0.884, RMSE=0.767 m
# r_EC: R²=0.852, RMSE=0.871 m
#
# Hybrid PINN (absolute-hinge) metrics:
# r_WE: R²=0.938, RMSE=0.733 m
# r_EW: R²=0.927, RMSE=0.908 m
# r_WC: R²=0.611, RMSE=0.758 m
# r_CW: R²=0.674, RMSE=0.839 m
# r_CE: R²=0.951, RMSE=0.499 m
# r_EC: R²=0.924, RMSE=0.623 m

# %%
# 10) PLOT RESULTS
for i, name in enumerate(Y_cols):
    fig, ax = plt.subplots(figsize=(10,4), tight_layout=True)
    ax.plot(times_aligned, R_true_aligned[:,i],   label='Obs', lw=2)
    ax.plot(times_aligned, R_lin_aligned[:,i],    label='LS-only', ls='--', lw=2)
    ax.plot(times_aligned, R_pred_full[:,i],      label='Hybrid PINN', lw=1)
    ax.set_title(f"{name}: LS R²={r2_score(R_true_aligned[:,i], R_lin_aligned[:,i]):.3f}, "
                 f"Hybrid R²={r2_score(R_true_aligned[:,i], R_pred_full[:,i]):.3f}")
    ax.legend(); ax.set_ylabel("Range (m)"); plt.show()

# %%
import os
# -----------------------------------------------------------------------------
# FORCE CPU PARALLELISM TO 48 CORES
# -----------------------------------------------------------------------------
os.environ["OMP_NUM_THREADS"]      = "48"
os.environ["MKL_NUM_THREADS"]      = "48"
os.environ["OPENBLAS_NUM_THREADS"] = "48"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib, pathlib

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error

import tensorflow as tf
from tensorflow.keras import layers, Model, backend as K, callbacks, regularizers

# configure TensorFlow threading
tf.config.threading.set_intra_op_parallelism_threads(48)
tf.config.threading.set_inter_op_parallelism_threads(48)

# =============================================================================
# ENHANCED HYBRID PINN: DROP OUT, L2 WEIGHT DECAY, LONGER LAGS
# – TRAIN ON LAST 70% – EVALUATE FULL SERIES
# =============================================================================

# 0) LOAD & FILTER
df_var = df_var.dropna().reset_index(drop=True)
df_var['Record Time'] = pd.to_datetime(df_var['Record Time'], utc=True)
df_var = df_var[df_var['Record Time'] >= pd.Timestamp(2022,9,7,tz='UTC')].reset_index(drop=True)

df = pd.DataFrame({
    'time': df_var['Record Time'],
    'p1':   df_var['p1'],  'p2': df_var['p2'],  'p3': df_var['p3'],
    'r_WE': df_var['d1'],  'r_EW': df_var['d2'],  'r_EC': df_var['d3'],
    'r_CE': df_var['d4'],  'r_WC': df_var['d5'],  'r_CW': df_var['d6'],
})
Y_cols = ['r_WE','r_EW','r_WC','r_CW','r_CE','r_EC']

# 1) TIME & SEASON + STANDARDIZED PRESSURES
t0 = df['time'].min()
df['t_days'] = (df['time'] - t0).dt.total_seconds() / 86400.0
ω = 2 * np.pi / 365.25
df['sin1'] = np.sin(ω * df['t_days'])
df['cos1'] = np.cos(ω * df['t_days'])

p1_std = (df['p1'] - df['p1'].mean()) / df['p1'].std()
p2_std = (df['p2'] - df['p2'].mean()) / df['p2'].std()
sin_t, cos_t = df['sin1'].values, df['cos1'].values

# 2) LEAST-SQUARES BLOCKS
A_CE = np.column_stack([np.ones_like(p2_std), p2_std, sin_t, cos_t])
x_CE,*_ = np.linalg.lstsq(A_CE, df['r_CE'], rcond=None)
x_EC,*_ = np.linalg.lstsq(A_CE, df['r_EC'], rcond=None)
r_CE_lin, r_EC_lin = A_CE @ x_CE, A_CE @ x_EC

A_CW = np.column_stack([np.ones_like(p1_std), p1_std, sin_t, cos_t])
x_CW,*_ = np.linalg.lstsq(A_CW, df['r_CW'], rcond=None)
x_WC,*_ = np.linalg.lstsq(A_CW, df['r_WC'], rcond=None)
r_CW_lin, r_WC_lin = A_CW @ x_CW, A_CW @ x_WC

A_EW = np.column_stack([np.ones_like(p1_std), p1_std, p2_std, sin_t, cos_t])
x_EW,*_ = np.linalg.lstsq(A_EW, df['r_EW'], rcond=None)
x_WE,*_ = np.linalg.lstsq(A_EW, df['r_WE'], rcond=None)
r_EW_lin, r_WE_lin = A_EW @ x_EW, A_EW @ x_WE

R_lin        = np.column_stack([r_WE_lin, r_EW_lin, r_WC_lin, r_CW_lin, r_CE_lin, r_EC_lin]).astype('float32')
R_obs        = df[Y_cols].values.astype('float32')
R_resid_full = (R_obs - R_lin).astype('float32')

# 3) FEATURE MATRIX + LONGER LAGS + LS FEATURES
lag_max = 7  # extend to 7 lags
df_feat = df[['p1','p2','p3','t_days','sin1','cos1']].copy()
for lag in range(1, lag_max+1):
    df_feat[f'p1_l{lag}'] = df['p1'].shift(lag)
    df_feat[f'p2_l{lag}'] = df['p2'].shift(lag)
    df_feat[f'p3_l{lag}'] = df['p3'].shift(lag)

for col, arr in zip(['r_WE_lin','r_EW_lin','r_WC_lin','r_CW_lin','r_CE_lin','r_EC_lin'],
                    [r_WE_lin, r_EW_lin, r_WC_lin, r_CW_lin, r_CE_lin, r_EC_lin]):
    df_feat[col] = arr

df_feat.dropna(inplace=True)
df_feat.reset_index(drop=True, inplace=True)

idx             = df_feat.index.values
X_raw           = df_feat.values.astype('float32')
R_resid_aligned = R_resid_full[idx]
R_lin_aligned   = R_lin[idx]
R_true_aligned  = R_obs[idx]
times_aligned   = df['time'].values[idx]

# 4) SCALE & SPLIT LAST 70%
scaler_X = StandardScaler().fit(X_raw)
Xs       = scaler_X.transform(X_raw)
scaler_R = StandardScaler().fit(R_resid_aligned)
Rs_s     = scaler_R.transform(R_resid_aligned)

N       = Xs.shape[0]
start   = int(0.30 * N)
X_train = Xs[start:]
Rs_train= Rs_s[start:]

# constants for un-scaling
mean_R  = K.constant(scaler_R.mean_.reshape((1,6)), dtype='float32')
scale_R = K.constant(scaler_R.scale_.reshape((1,6)), dtype='float32')

# indices for LS features
feat_cols = df_feat.columns.tolist()
i_CE, i_EC = feat_cols.index('r_CE_lin'), feat_cols.index('r_EC_lin')
i_CW, i_WC = feat_cols.index('r_CW_lin'), feat_cols.index('r_WC_lin')
i_WE, i_EW = feat_cols.index('r_WE_lin'), feat_cols.index('r_EW_lin')

# 5) BUILD 3-HEAD PINN WITH DROPOUT & L2
w_mse, w_sym, w_clo, w_hinge = 10.0, 0.5, 0.01, 5.0
l2 = 1e-5  # weight decay
d  = 0.3   # dropout rate

inp    = layers.Input(shape=(Xs.shape[1],))
shared = layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(l2))(inp)
shared = layers.Dropout(d)(shared)
shared = layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(l2))(shared)
shared = layers.Dropout(d)(shared)

east = layers.Lambda(lambda x: tf.gather(x, [i_CE, i_EC], axis=1))(inp)
west = layers.Lambda(lambda x: tf.gather(x, [i_CW, i_WC], axis=1))(inp)
mid  = layers.Lambda(lambda x: tf.gather(x, [i_WE, i_EW], axis=1))(inp)

def head_block(xf):
    xh = layers.Concatenate()([shared, xf])
    xh = layers.Dense(32, activation='relu',
                     kernel_regularizer=regularizers.l2(l2))(xh)
    xh = layers.Dropout(d)(xh)
    return layers.Dense(2, activation='linear')(xh)

r_CE_p, r_EC_p = tf.split(head_block(east), 2, axis=1)
r_CW_p, r_WC_p = tf.split(head_block(west), 2, axis=1)
r_WE_p, r_EW_p = tf.split(head_block(mid), 2, axis=1)

resid_out = layers.Concatenate()([
    r_WE_p, r_EW_p,
    r_WC_p, r_CW_p,
    r_CE_p, r_EC_p
])
model = Model(inp, resid_out)

# 6) LOSS WITH ABSOLUTE-ERROR HINGE
def loss_fn(r_true_s, r_pred_s):
    e_ls     = r_true_s * scale_R + mean_R
    pred_res = r_pred_s * scale_R + mean_R
    e_hybrid = e_ls - pred_res

    L_mse  = K.mean(K.square(r_true_s - r_pred_s))
    CE, EC = r_pred_s[:,4], r_pred_s[:,5]
    CW, WC = r_pred_s[:,3], r_pred_s[:,2]
    L_sym  = K.mean(K.square(CE - EC) + K.square(CW - WC))
    dCE  = CE[1:] - CE[:-1]; dCW = CW[1:] - CW[:-1]
    dEW  = r_pred_s[1:,1] - r_pred_s[:-1,1]
    L_clo= K.mean(K.square(dCE + dCW - dEW))

    delta  = K.abs(e_hybrid) - K.abs(e_ls)
    L_hinge= K.mean(K.maximum(delta, 0.0))

    return (w_mse * L_mse
          + w_sym * L_sym
          + w_clo * L_clo
          + w_hinge * L_hinge)

model.compile(optimizer='adam', loss=loss_fn)
es = callbacks.EarlyStopping(monitor='loss', patience=30, restore_best_weights=True)

# 7) TRAIN ON LAST 70%
model.fit(X_train, Rs_train, epochs=300, batch_size=len(X_train),
          callbacks=[es], verbose=1)

# 8) PREDICT & RECONSTRUCT FULL SERIES
Rs_pred_s   = model.predict(Xs)
Rs_pred     = scaler_R.inverse_transform(Rs_pred_s)
R_pred_full = R_lin_aligned + Rs_pred

# 9) EVALUATE & PRINT METRICS
print("LS-only metrics:")
for i, name in enumerate(Y_cols):
    r2_lin  = r2_score(R_true_aligned[:,i], R_lin_aligned[:,i])
    rmse_lin= mean_squared_error(R_true_aligned[:,i], R_lin_aligned[:,i], squared=False)
    print(f"{name}: R²={r2_lin:.3f}, RMSE={rmse_lin:.3f} m")

print("\nHybrid PINN (enhanced) metrics:")
for i, name in enumerate(Y_cols):
    r2_h   = r2_score(R_true_aligned[:,i], R_pred_full[:,i])
    rmse_h = mean_squared_error(R_true_aligned[:,i], R_pred_full[:,i], squared=False)
    print(f"{name}: R²={r2_h:.3f}, RMSE={rmse_h:.3f} m")
# Out:
# Epoch 1/300
# 1/1 [==============================] - 1s 1s/step - loss: 19.4481
# Epoch 2/300
# 1/1 [==============================] - 0s 11ms/step - loss: 17.7248
# Epoch 3/300
# 1/1 [==============================] - 0s 10ms/step - loss: 16.1258
# Epoch 4/300
# 1/1 [==============================] - 0s 10ms/step - loss: 15.0424
# Epoch 5/300
# 1/1 [==============================] - 0s 9ms/step - loss: 14.1660
# Epoch 6/300
# 1/1 [==============================] - 0s 9ms/step - loss: 13.5213
# Epoch 7/300
# 1/1 [==============================] - 0s 9ms/step - loss: 12.8221
# Epoch 8/300
# 1/1 [==============================] - 0s 9ms/step - loss: 12.3140
# Epoch 9/300
# 1/1 [==============================] - 0s 9ms/step - loss: 12.0335
# Epoch 10/300
# 1/1 [==============================] - 0s 9ms/step - loss: 11.6771
# Epoch 11/300
# 1/1 [==============================] - 0s 9ms/step - loss: 11.5543
# Epoch 12/300
# 1/1 [==============================] - 0s 9ms/step - loss: 11.2116
# Epoch 13/300
# 1/1 [==============================] - 0s 9ms/step - loss: 11.0641
# Epoch 14/300
# 1/1 [==============================] - 0s 9ms/step - loss: 10.8242
# Epoch 15/300
# 1/1 [==============================] - 0s 8ms/step - loss: 10.7457
# Epoch 16/300
# 1/1 [==============================] - 0s 9ms/step - loss: 10.5190
# Epoch 17/300
# 1/1 [==============================] - 0s 8ms/step - loss: 10.3770
# Epoch 18/300
# 1/1 [==============================] - 0s 9ms/step - loss: 10.2789
# Epoch 19/300
# 1/1 [==============================] - 0s 8ms/step - loss: 10.2279
# Epoch 20/300
# 1/1 [==============================] - 0s 9ms/step - loss: 10.1334
# Epoch 21/300
# 1/1 [==============================] - 0s 9ms/step - loss: 10.0223
# Epoch 22/300
# 1/1 [==============================] - 0s 8ms/step - loss: 9.9039
# Epoch 23/300
# 1/1 [==============================] - 0s 7ms/step - loss: 9.9117
# Epoch 24/300
# 1/1 [==============================] - 0s 9ms/step - loss: 9.7478
# Epoch 25/300
# 1/1 [==============================] - 0s 7ms/step - loss: 9.7586
# Epoch 26/300
# 1/1 [==============================] - 0s 8ms/step - loss: 9.6462
# Epoch 27/300
# 1/1 [==============================] - 0s 8ms/step - loss: 9.5219
# Epoch 28/300
# 1/1 [==============================] - 0s 8ms/step - loss: 9.4890
# Epoch 29/300
# 1/1 [==============================] - 0s 8ms/step - loss: 9.4051
# Epoch 30/300
# 1/1 [==============================] - 0s 8ms/step - loss: 9
300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9786
# Epoch 240/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9213
# Epoch 241/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9250
# Epoch 242/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9340
# Epoch 243/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9241
# Epoch 244/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9692
# Epoch 245/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9342
# Epoch 246/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9452
# Epoch 247/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9060
# Epoch 248/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9487
# Epoch 249/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.8483
# Epoch 250/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9068
# Epoch 251/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8621
# Epoch 252/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8504
# Epoch 253/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.8115
# Epoch 254/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8501
# Epoch 255/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8563
# Epoch 256/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.7925
# Epoch 257/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8813
# Epoch 258/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8388
# Epoch 259/300
# 1/1 [==============================] - 0s 9ms/step - loss: 4.7845
# Epoch 260/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8025
# Epoch 261/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8192
# Epoch 262/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8295
# Epoch 263/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8284
# Epoch 264/300
# 1/1 [==============================] - 0s 9ms/step - loss: 4.7597
# Epoch 265/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8169
# Epoch 266/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.7306
# Epoch 267/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.7259
# Epoch 268/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8294
# Epoch 269/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7489
# Epoch 270/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7442
# Epoch 271/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8213
# Epoch 272/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7324
# Epoch 273/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7288
# Epoch 274/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7778
# Epoch 275/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.6937
# Epoch 276/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.6236
# Epoch 277/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6988
# Epoch 278/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7202
# Epoch 279/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6905
# Epoch 280/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6660
# Epoch 281/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7238
# Epoch 282/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6756
# Epoch 283/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.6195
# Epoch 284/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.5145
# Epoch 285/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6351
# Epoch 286/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6390
# Epoch 287/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6182
# Epoch 288/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6991
# Epoch 289/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6043
# Epoch 290/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6066
# Epoch 291/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5967
# Epoch 292/300
# 1/1 [==============================] - 0s 8ms/step - loss: 4.4908
# Epoch 293/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6657
# Epoch 294/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6301
# Epoch 295/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6775
# Epoch 296/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5981
# Epoch 297/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5233
# Epoch 298/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6351
# Epoch 299/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5535
# Epoch 300/300
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5933
# 136/136 [==============================] - 0s 925us/step
# LS-only metrics:
# r_WE: R²=0.826, RMSE=1.216 m
# r_EW: R²=0.740, RMSE=1.700 m
# r_WC: R²=0.545, RMSE=0.819 m
# r_CW: R²=0.575, RMSE=0.957 m
# r_CE: R²=0.883, RMSE=0.767 m
# r_EC: R²=0.851, RMSE=0.870 m
#
# Hybrid PINN (enhanced) metrics:
# r_WE: R²=0.885, RMSE=0.986 m
# r_EW: R²=0.789, RMSE=1.529 m
# r_WC: R²=0.676, RMSE=0.691 m
# r_CW: R²=0.689, RMSE=0.819 m
# r_CE: R²=0.932, RMSE=0.586 m
# r_EC: R²=0.908, RMSE=0.686 m

# %%
# 10) PLOT RESULTS
for i, name in enumerate(Y_cols):
    fig, ax = plt.subplots(figsize=(10,4), tight_layout=True)
    ax.plot(times_aligned, R_true_aligned[:,i],   label='Obs', lw=2)
    ax.plot(times_aligned, R_lin_aligned[:,i],    label='LS-only', ls='--', lw=2)
    ax.plot(times_aligned, R_pred_full[:,i],      label='Hybrid PINN', lw=1)
    ax.set_title(f"{name}: LS R²={r2_score(R_true_aligned[:,i], R_lin_aligned[:,i]):.3f}, "
                 f"Hybrid R²={r2_score(R_true_aligned[:,i], R_pred_full[:,i]):.3f}")
    ax.legend(); ax.set_ylabel("Range (m)")
    plt.show()
